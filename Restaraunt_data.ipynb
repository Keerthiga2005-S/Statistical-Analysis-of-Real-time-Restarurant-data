# %%
import pandas as pd

# %%
data=pd.read_csv('Restaurant.csv')

# %%
data
# Out:
#           DATE   TIME  INVOICE_NO            ITEM  QUANTITY   RATE  SUB_TOTAL  \
# 0     01.10.23  23.40         174         PAROTTA       4.0   18.0       72.0
# 1     01.10.23  23.40         174         OMLETTE       2.0   18.0       36.0
# 2     01.10.23  23.36         173            DOSA       3.0   20.0       60.0
# 3     01.10.23  23.36         173         PAROTTA       2.0   18.0       36.0
# 4     01.10.23  23.36         173          KALAKI       1.0   15.0       15.0
# ..         ...    ...         ...             ...       ...    ...        ...
# 526  2.10.2285  21.53         146  VEG FRIED RICE       1.0   80.0       80.0
# 527  2.10.2286  21.53         145         PAROTTA       4.0   18.0       72.0
# 528  2.10.2287  21.53         147  BUTTER CHICKEN       1.0  130.0      130.0
# 529  2.10.2288  21.53         147         PAROTTA       2.0   18.0       36.0
# 530  2.10.2289  21.54         148         PAROTTA       3.0   18.0       54.0
#
#      AMOUNT  DAY
# ...

# %%
d=data['AMOUNT'].sum()
d
# Out:
# np.float64(41559.0)

# %%
de=data['DATE'].iloc[1:2]
de
# Out:
# 1    01.10.23
# Name: DATE, dtype: object

# %%
filtered=data[data['DATE']=='01.10.23']
filtered
# Out:
#          DATE   TIME  INVOICE_NO              ITEM  QUANTITY   RATE  \
# 0    01.10.23  23.40         174           PAROTTA       4.0   18.0
# 1    01.10.23  23.40         174           OMLETTE       2.0   18.0
# 2    01.10.23  23.36         173              DOSA       3.0   20.0
# 3    01.10.23  23.36         173           PAROTTA       2.0   18.0
# 4    01.10.23  23.36         173            KALAKI       1.0   15.0
# ..        ...    ...         ...               ...       ...    ...
# 254  01.10.23  12.36           7            KALAKI       1.0   15.0
# 255  01.10.23  12.15           5           PAROTTA       2.0   18.0
# 256  01.10.23  12.15           4  CHICKEN BIRIYANI       2.0  110.0
# 257  01.10.23  12.15           4    CHILLI CHICKEN       1.0  100.0
# 258  01.10.23  12.08           3         CHAPPATHI       3.0   18.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 0         72.0     NaN    1
# 1         36.0   108.0    1
# 2         60.0     NaN    1
# 3         36.0     NaN    1
# ...

# %%
filtered['AMOUNT'].mean()
# Out:
# np.float64(184.2280701754386)

# %%
invoice=data[data['INVOICE_NO']==117]
invoice
# Out:
#           DATE   TIME  INVOICE_NO                ITEM  QUANTITY   RATE  \
# 80    01.10.23  20.29         117          GHEE ROAST       2.0   50.0
# 81    01.10.23  20.29         117           EGG ROAST       2.0   50.0
# 82    01.10.23  20.29         117     CHICKEN NOODLES       1.0  100.0
# 83    01.10.23  20.29         117      CHILLI CHICKEN       1.0  100.0
# 84    01.10.23  20.29         117         COOL DRINKS       2.0   15.0
# 491  2.10.2250  21.00         117   SCHEZWAN EGG RICE       1.0   95.0
# 492  2.10.2251  21.00         117  CHICKEN FRIED RICE       1.0  100.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 80       100.0     NaN    1
# 81       100.0     NaN    1
# 82       100.0     NaN    1
# 83       100.0     NaN    1
# 84        30.0   430.0    1
# 491       95.0     NaN    2
# 492      100.0   195.0    2

# %%
invoice['AMOUNT'].sum()
# Out:
# np.float64(625.0)

# %%
import matplotlib.pyplot as plt
fil=data[data['ITEM']=='GHEE ROAST']
fil
# Out:
#         DATE   TIME  INVOICE_NO        ITEM  QUANTITY  RATE  SUB_TOTAL  \
# 36  01.10.23  22.36         154  GHEE ROAST       1.0  50.0       50.0
# 80  01.10.23  20.29         117  GHEE ROAST       2.0  50.0      100.0
#
#     AMOUNT  DAY
# 36     NaN    1
# 80     NaN    1

# %%
fil['AMOUNT'].sum()
# Out:
# np.float64(0.0)

# %%
#To find the top 5 sales item
b=data.groupby('ITEM')['SUB_TOTAL'].sum()
b
# Out:
# ITEM
# BOILED EGG              15.0
# BUCKET BIRIYNI HALF    530.0
# BUN PAROTTA            500.0
# BUTTER CHICKEN         260.0
# CHAPPATHI              900.0
#                        ...
# VEG NOODLES             80.0
# VEG PULAV              340.0
# VEGG FRIED RICE         80.0
# VEGG NOODLES            80.0
# WATER BOTTLE            40.0
# Name: SUB_TOTAL, Length: 91, dtype: float64

# %%
c=b.sort_values(ascending=False)
c
# Out:
# ITEM
# PAROTTA             5346.0
# CHICKEN BIRIYANI    5060.0
# MUTTON BIRIYANI     2550.0
# PLAIN BIRIYANI      2240.0
# DOSA                2160.0
#                      ...
# LOLLIPOP              35.0
# GOLI 1                30.0
# CURD                  30.0
# BOILED EGG            15.0
# MISCELLE               0.0
# Name: SUB_TOTAL, Length: 91, dtype: float64

# %%
d=c.head(5)
d
# Out:
# ITEM
# PAROTTA             5346.0
# CHICKEN BIRIYANI    5060.0
# MUTTON BIRIYANI     2550.0
# PLAIN BIRIYANI      2240.0
# DOSA                2160.0
# Name: SUB_TOTAL, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.bar(d.index,d.values)
# Out:
# <BarContainer object of 5 artists>

# %%
quan=data.groupby('ITEM')['QUANTITY'].sum().sort_values(ascending=False).head(5)
quan
# Out:
# ITEM
# PAROTTA             297.0
# DOSA                108.0
# CHAPPATHI            50.0
# KALAKI               49.0
# CHICKEN BIRIYANI     46.0
# Name: QUANTITY, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.bar(quan.index,quan.values)
# Out:
# <BarContainer object of 5 artists>

# %%
fil=data[data['DATE']=='2.10.2023']
fil
# Out:
#           DATE   TIME  INVOICE_NO               ITEM  QUANTITY   RATE  \
# 259  2.10.2023  12.29           1   CHICKEN BIRIYANI       1.0  110.0
# 260  2.10.2023  12.32           2  CHICKEN FICE RICE       1.0  100.0
# 261  2.10.2023  12.32           2            GOBI 65       1.0   60.0
# 262  2.10.2023  12.32           2        EGG PAROTTA       1.0   70.0
# 263  2.10.2023  12.34           3            PAROTTA      12.0   18.0
# 264  2.10.2023  12.34           3       EGG BIRIYANI       1.0   80.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 259      110.0   110.0    2
# 260      100.0   230.0    2
# 261       60.0     NaN    2
# 262       70.0     NaN    2
# 263      216.0   296.0    2
# 264       80.0     NaN    2

# %%
y=fil.groupby('ITEM')['QUANTITY'].sum().sort_values(ascending=True)
y
# Out:
# ITEM
# CHICKEN BIRIYANI      1.0
# CHICKEN FICE RICE     1.0
# EGG BIRIYANI          1.0
# EGG PAROTTA           1.0
# GOBI 65               1.0
# PAROTTA              12.0
# Name: QUANTITY, dtype: float64

# %%
fil=data.groupby('INVOICE_NO')['AMOUNT'].sum().sort_values(ascending=False)
fil
# Out:
# INVOICE_NO
# 63     941.0
# 68     892.0
# 66     835.0
# 58     808.0
# 159    768.0
#        ...
# 106     40.0
# 17      36.0
# 5       36.0
# 72      36.0
# 95      35.0
# Name: AMOUNT, Length: 153, dtype: float64

# %%
plt.bar(fil.index,fil.values)
# Out:
# <BarContainer object of 153 artists>

# %%
fil=data[data['DATE']=='01.10.23']
fil
# Out:
#          DATE   TIME  INVOICE_NO              ITEM  QUANTITY   RATE  \
# 0    01.10.23  23.40         174           PAROTTA       4.0   18.0
# 1    01.10.23  23.40         174           OMLETTE       2.0   18.0
# 2    01.10.23  23.36         173              DOSA       3.0   20.0
# 3    01.10.23  23.36         173           PAROTTA       2.0   18.0
# 4    01.10.23  23.36         173            KALAKI       1.0   15.0
# ..        ...    ...         ...               ...       ...    ...
# 254  01.10.23  12.36           7            KALAKI       1.0   15.0
# 255  01.10.23  12.15           5           PAROTTA       2.0   18.0
# 256  01.10.23  12.15           4  CHICKEN BIRIYANI       2.0  110.0
# 257  01.10.23  12.15           4    CHILLI CHICKEN       1.0  100.0
# 258  01.10.23  12.08           3         CHAPPATHI       3.0   18.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 0         72.0     NaN    1
# 1         36.0   108.0    1
# 2         60.0     NaN    1
# 3         36.0     NaN    1
# ...

# %%
f=fil[fil['ITEM']=='PAROTTA']
f
# Out:
#          DATE   TIME  INVOICE_NO     ITEM  QUANTITY  RATE  SUB_TOTAL  AMOUNT  \
# 0    01.10.23  23.40         174  PAROTTA       4.0  18.0       72.0     NaN
# 3    01.10.23  23.36         173  PAROTTA       2.0  18.0       36.0     NaN
# 5    01.10.23  23.27         172  PAROTTA       6.0  18.0      108.0     NaN
# 17   01.10.23  23.24         170  PAROTTA       1.0  18.0       18.0     NaN
# 19   01.10.23  15.34          68  PAROTTA      44.0  18.0      792.0   792.0
# 30   01.10.23  22.52         162  PAROTTA       3.0  18.0       54.0   314.0
# 42   01.10.23  22.35         153  PAROTTA       4.0  18.0       72.0    72.0
# 49   01.10.23  22.14         146  PAROTTA       1.0  18.0       18.0     NaN
# 55   01.10.23  21.52         140  PAROTTA       6.0  18.0      108.0     NaN
# 65   01.10.23  21.05         129  PAROTTA       2.0  18.0       36.0    36.0
# 72   01.10.23  20.56         126  PAROTTA       5.0  18.0       90.0    90.0
# ...

# %%
data.loc[(data['DATE']>='01.10.23') & data['DATE']<=
# Out:
#   File "/tmp/ipython-input-63-2284231012.py", line 1
#     a=fil['TIME']>=12.00 && fil['TIME']<=18.00
#                           ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-62-3714475359.py in <cell line: 0>()
# ----> 1 o=data[data['TIME']<=12.00 and data['TIME']<=18.00]
#       2 o
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
